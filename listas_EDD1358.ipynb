# %% [markdown]
# <a href="https://colab.research.google.com/github/ludwin1/estructura-de-datos/blob/main/listas_EDD1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Nodo:
  def __init__(self , value , siguiente = None):
    self.data = value
    self.next = siguiente

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png](data:image/png;base64,...))

# %%
head =Nodo(30)
print(head.data)
print(head.next)
# Out:
# 30
# None

# %%
punto_entrada = Nodo(20)
punto_entrada.next = Nodo(15)
print( punto_entrada.next.data)
print( punto_entrada.next.next)

print(head2.data)
#print(punto_entrada.next)
print(head2.next)
#print(punto_entrada.next.next)
print("hacer lo mismo pero con el segundo metodo")

punto_entrada = Nodo(20, Nodo(15))
print(punto_entrada.data)
print(punto_entrada.next.data)
# Out:
# 15
# None
# 20
# <__main__.Nodo object at 0x7fd65a87af90>
